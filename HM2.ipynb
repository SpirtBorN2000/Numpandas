# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
x = [1,2,3,4,5,6,7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %% [markdown]
# # Задание 1

# %%
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Задание 2

# %%
t = np.linspace(0,10,51)
t
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
f = np.sin(t)
f
# Out:
# array([ 0.        ,  0.19866933,  0.38941834,  0.56464247,  0.71735609,
#         0.84147098,  0.93203909,  0.98544973,  0.9995736 ,  0.97384763,
#         0.90929743,  0.8084964 ,  0.67546318,  0.51550137,  0.33498815,
#         0.14112001, -0.05837414, -0.2555411 , -0.44252044, -0.61185789,
#        -0.7568025 , -0.87157577, -0.95160207, -0.993691  , -0.99616461,
#        -0.95892427, -0.88345466, -0.77276449, -0.63126664, -0.46460218,
#        -0.2794155 , -0.0830894 ,  0.1165492 ,  0.31154136,  0.49411335,
#         0.6569866 ,  0.79366786,  0.8987081 ,  0.96791967,  0.99854335,
#         0.98935825,  0.94073056,  0.85459891,  0.7343971 ,  0.58491719,
#         0.41211849,  0.22288991,  0.02477543, -0.17432678, -0.36647913,
#        -0.54402111])

# %%
plt.plot(t,f,color = 'green')
plt.title('График f(t)',fontsize = 16, fontweight = 'bold')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.axis([0.5,9.5,-2.5,2.5])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Задание 3

# %%
x = np.linspace(-3,3,51)
x
# Out:
# array([-3.  , -2.88, -2.76, -2.64, -2.52, -2.4 , -2.28, -2.16, -2.04,
#        -1.92, -1.8 , -1.68, -1.56, -1.44, -1.32, -1.2 , -1.08, -0.96,
#        -0.84, -0.72, -0.6 , -0.48, -0.36, -0.24, -0.12,  0.  ,  0.12,
#         0.24,  0.36,  0.48,  0.6 ,  0.72,  0.84,  0.96,  1.08,  1.2 ,
#         1.32,  1.44,  1.56,  1.68,  1.8 ,  1.92,  2.04,  2.16,  2.28,
#         2.4 ,  2.52,  2.64,  2.76,  2.88,  3.  ])

# %%
y1 = x**2
y2 = 2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig,ax = plt.subplots(nrows = 2,ncols = 2)
ax1,ax2,ax3,ax4 = ax.flatten()
ax1.plot(x,y1)
ax1.axis([-5,5,0,5])
ax2.plot(x,y2)
ax3.plot(x,y3)
ax4.plot(x,y4)
ax1.set_title('График у1')
ax2.set_title('График у2')
ax3.set_title('График у3')
ax4.set_title('График у4')
plt.subplots_adjust(wspace = 0.3,hspace = 0.3)
fig.set_size_inches(8,6)

# %% [markdown]
# # Задание 4

# %%
df = pd.read_csv("creditcard.csv")
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
dfclassvalues = df['Class'].value_counts()
dfclassvalues.plot(kind = 'bar')

# %%
dfclassvalues.plot(kind = 'bar',logy = True)

# %%
hist_class0 = plt.hist(df['V1'], bins = 20)

# %%
df[df['Class'] == 1 ]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
plt.hist(param1, bins = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-9739586c4a11> in <module>
# ----> 1 plt.hist(param1, bins = 20)
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2636         label=None, stacked=False, normed=None, *, data=None,
#    2637         **kwargs):
# -> 2638     return gca().hist(
#    2639         x, bins=bins, range=range, density=density, weights=weights,
#    2640         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in gca(**kwargs)
#     924     matplotlib.figure.Figure.gca : The figure's gca method.
#     925     """
# --> 926     return gcf().gca(**kwargs)
#     927
#     928
#
# ...
